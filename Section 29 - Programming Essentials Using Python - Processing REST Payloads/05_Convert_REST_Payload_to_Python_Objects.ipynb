# %% [markdown]
# ## Convert REST Payload to Python Objects
#
# Let us understand how we can convert REST `GET` Payload to appropriate Python Objects.
#
#    * We have already seen that the `payload` is of type `str`. Also, it contains valid `json`. It can be a simple JSON Document os JSON Array.
#
# Here are the steps involved in converting REST Payload to Python Objects.
#
#    * Invoke REST API by passing valid URL. It will create response object.
#    * Using response object, we can invoke `json()`. It will return Python dict or Python list. The list typically contain dicts.
#    * Once it is converted to Python dict or list we can further process data using appropriate Python APIs as per our requirements.

# %%
import requests

# %% [markdown]
# * Example for simple JSON to `dict`.

# %%
# !curl https://api.github.com

# %%
payload = requests.get('https://api.github.com').content.decode('utf-8')

# %%
# A string with valid JSON
payload
# Out:
# '{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_search_url":"https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}","notifications_url":"https://api.github.com/notifications","organization_url":"https://api.github.com/orgs/{org}","organization_repositories_url":"https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}","organization_teams_url":"https://api.github.com/orgs/{org}/teams","public_gists_url":"https://api.github.com/gists/public","rate_limit_url":"https://api.github.com/rate_limit","repository_url":"https://api.github.com/repos/{owner}/{repo}","repository_search_url":"https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}","current_user_repositories_url":"https://api.github.com/user/repos{?type,page,per_page,sort}","starred_url":"https://api.github.com/user/starred{/owner}{/repo}","starred_gists_url":"https://api.github.com/gists/starred","topic_search_url":"https://api.github.com/search/topics?q={query}{&page,per_page}","user_url":"https://api.github.com/users/{user}","user_organizations_url":"https://api.github.com/user/orgs","user_repositories_url":"https://api.github.com/users/{user}/repos{?type,page,per_page,sort}","user_search_url":"https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"}'

# %%
# returns Python dict directly
payload_dict = requests.get('https://api.github.com').json()

# %%
type(payload_dict)
# Out:
# dict

# %%
# It is of type dict
payload_dict
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
#  'issues_url': 'https://api.github.com/issues',
#  'keys_url': 'https://api.github.com/user/keys',
#  'label_search_url': 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}',
#  'notifications_url': 'https://api.github.com/notifications',
#  'organization_url': 'https://api.github.com/orgs/{org}',
#  'organization_repositories_url': 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}',
#  'organization_teams_url': 'https://api.github.com/orgs/{org}/teams',
#  'public_gists_url': 'https://api.github.com/gists/public',
#  'rate_limit_url': 'https://api.github.com/rate_limit',
#  'repository_url': 'https://api.github.com/repos/{owner}/{repo}',
#  'repository_search_url': 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}',
#  'current_user_repositories_url': 'https://api.github.com/user/repos{?type,page,per_page,sort}',
#  'starred_url': 'https://api.github.com/user/starred{/owner}{/repo}',
#  'starred_gists_url': 'https://api.github.com/gists/starred',
#  'topic_search_url': 'https://api.github.com/search/topics?q={query}{&page,per_page}',
#  'user_url': 'https://api.github.com/users/{user}',
#  'user_organizations_url': 'https://api.github.com/user/orgs',
#  'user_repositories_url': 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}',
#  'user_search_url': 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'}

# %%
payload_dict.keys()
# Out:
# dict_keys(['current_user_url', 'current_user_authorizations_html_url', 'authorizations_url', 'code_search_url', 'commit_search_url', 'emails_url', 'emojis_url', 'events_url', 'feeds_url', 'followers_url', 'following_url', 'gists_url', 'hub_url', 'issue_search_url', 'issues_url', 'keys_url', 'label_search_url', 'notifications_url', 'organization_url', 'organization_repositories_url', 'organization_teams_url', 'public_gists_url', 'rate_limit_url', 'repository_url', 'repository_search_url', 'current_user_repositories_url', 'starred_url', 'starred_gists_url', 'topic_search_url', 'user_url', 'user_organizations_url', 'user_repositories_url', 'user_search_url'])

# %%
payload_dict.values()
# Out:
# dict_values(['https://api.github.com/user', 'https://github.com/settings/connections/applications{/client_id}', 'https://api.github.com/authorizations', 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}', 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}', 'https://api.github.com/user/emails', 'https://api.github.com/emojis', 'https://api.github.com/events', 'https://api.github.com/feeds', 'https://api.github.com/user/followers', 'https://api.github.com/user/following{/target}', 'https://api.github.com/gists{/gist_id}', 'https://api.github.com/hub', 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}', 'https://api.github.com/issues', 'https://api.github.com/user/keys', 'https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}', 'https://api.github.com/notifications', 'https://api.github.com/orgs/{org}', 'https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}', 'https://api.github.com/orgs/{org}/teams', 'https://api.github.com/gists/public', 'https://api.github.com/rate_limit', 'https://api.github.com/repos/{owner}/{repo}', 'https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}', 'https://api.github.com/user/repos{?type,page,per_page,sort}', 'https://api.github.com/user/starred{/owner}{/repo}', 'https://api.github.com/gists/starred', 'https://api.github.com/search/topics?q={query}{&page,per_page}', 'https://api.github.com/users/{user}', 'https://api.github.com/user/orgs', 'https://api.github.com/users/{user}/repos{?type,page,per_page,sort}', 'https://api.github.com/search/users?q={query}{&page,per_page,sort,order}'])

# %%
payload_dict['current_user_url']
# Out:
# 'https://api.github.com/user'

# %% [markdown]
# * Example for JSON Array to `list`.

# %%
! curl https://github.com/romulovieira777?tab=repositories

# %%
import requests

# %%
url = "https://api.github.com/users/romulovieira777/repos"

# %%
type(url)
# Out:
# str

# %%
response = requests.get(url)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.json()
# Out:
# [{'id': 251727685,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTE3Mjc2ODU=',
#   'name': '16-Bingo',
#   'full_name': 'romulovieira777/16-Bingo',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/16-Bingo',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/16-Bingo',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/deployments',
#   'created_at': '2020-03-31T20:47:26Z',
#   'updated_at': '2020-05-26T12:33:53Z',
#   'pushed_at': '2020-03-31T20:53:40Z',
#   'git_url': 'git://github.com/romulovieira777/16-Bingo.git',
#   'ssh_url': 'git@github.com:romulovieira777/16-Bingo.git',
#   'clone_url': 'https://github.com/romulovieira777/16-Bingo.git',
#   'svn_url': 'https://github.com/romulovieira777/16-Bingo',
#   'homepage': None,
#   'size': 6,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252269073,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIyNjkwNzM=',
#   'name': '17_Antecessor_e_Sucessor',
#   'full_name': 'romulovieira777/17_Antecessor_e_Sucessor',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/17_Antecessor_e_Sucessor',
#   'description': '17 - Antecessor e Sucessor',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor/deployments',
#   'created_at': '2020-04-01T19:33:18Z',
#   'updated_at': '2020-05-26T12:33:32Z',
#   'pushed_at': '2020-04-01T19:44:42Z',
#   'git_url': 'git://github.com/romulovieira777/17_Antecessor_e_Sucessor.git',
#   'ssh_url': 'git@github.com:romulovieira777/17_Antecessor_e_Sucessor.git',
#   'clone_url': 'https://github.com/romulovieira777/17_Antecessor_e_Sucessor.git',
#   'svn_url': 'https://github.com/romulovieira777/17_Antecessor_e_Sucessor',
#   'homepage': None,
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252271807,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIyNzE4MDc=',
#   'name': '18_Menor_de_3',
#   'full_name': 'romulovieira777/18_Menor_de_3',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/18_Menor_de_3',
#   'description': '18 - Menor de 3',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/18_Menor_de_3/deployments',
#   'created_at': '2020-04-01T19:47:13Z',
#   'updated_at': '2020-05-26T12:34:10Z',
#   'pushed_at': '2020-04-01T19:51:32Z',
#   'git_url': 'git://github.com/romulovieira777/18_Menor_de_3.git',
#   'ssh_url': 'git@github.com:romulovieira777/18_Menor_de_3.git',
#   'clone_url': 'https://github.com/romulovieira777/18_Menor_de_3.git',
#   'svn_url': 'https://github.com/romulovieira777/18_Menor_de_3',
#   'homepage': None,
#   'size': 6,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252275529,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIyNzU1Mjk=',
#   'name': '19-Media_dos_Alunos',
#   'full_name': 'romulovieira777/19-Media_dos_Alunos',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/19-Media_dos_Alunos',
#   'description': '19 - Média dos alunos',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos/deployments',
#   'created_at': '2020-04-01T20:06:27Z',
#   'updated_at': '2020-05-26T12:33:02Z',
#   'pushed_at': '2020-04-01T20:10:34Z',
#   'git_url': 'git://github.com/romulovieira777/19-Media_dos_Alunos.git',
#   'ssh_url': 'git@github.com:romulovieira777/19-Media_dos_Alunos.git',
#   'clone_url': 'https://github.com/romulovieira777/19-Media_dos_Alunos.git',
#   'svn_url': 'https://github.com/romulovieira777/19-Media_dos_Alunos',
#   'homepage': None,
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252273289,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTIyNzMyODk=',
#   'name': '2-3_Numeros_em_Ordem_Crescente',
#   'full_name': 'romulovieira777/2-3_Numeros_em_Ordem_Crescente',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/2-3_Numeros_em_Ordem_Crescente',
#   'description': '2 - 3 Números em Ordem Crescente',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente/deployments',
#   'created_at': '2020-04-01T19:54:52Z',
#   'updated_at': '2020-05-26T12:34:30Z',
#   'pushed_at': '2020-04-01T20:02:36Z',
#   'git_url': 'git://github.com/romulovieira777/2-3_Numeros_em_Ordem_Crescente.git',
#   'ssh_url': 'git@github.com:romulovieira777/2-3_Numeros_em_Ordem_Crescente.git',
#   'clone_url': 'https://github.com/romulovieira777/2-3_Numeros_em_Ordem_Crescente.git',
#   'svn_url': 'https://github.com/romulovieira777/2-3_Numeros_em_Ordem_Crescente',
#   'homepage': None,
#   'size': 6,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252601219,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTI2MDEyMTk=',
#   'name': '20-Loop_de_Inteiros',
#   'full_name': 'romulovieira777/20-Loop_de_Inteiros',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/20-Loop_de_Inteiros',
#   'description': '20 -  Loop de inteiros',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros/deployments',
#   'created_at': '2020-04-03T01:10:55Z',
#   'updated_at': '2020-05-26T12:32:31Z',
#   'pushed_at': '2020-04-03T01:15:02Z',
#   'git_url': 'git://github.com/romulovieira777/20-Loop_de_Inteiros.git',
#   'ssh_url': 'git@github.com:romulovieira777/20-Loop_de_Inteiros.git',
#   'clone_url': 'https://github.com/romulovieira777/20-Loop_de_Inteiros.git',
#   'svn_url': 'https://github.com/romulovieira777/20-Loop_de_Inteiros',
#   'homepage': None,
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252813731,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTI4MTM3MzE=',
#   'name': '22-Tabuada',
#   'full_name': 'romulovieira777/22-Tabuada',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/22-Tabuada',
#   'description': '22 - Tabuada',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/22-Tabuada',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/22-Tabuada/deployments',
#   'created_at': '2020-04-03T18:48:20Z',
#   'updated_at': '2020-05-26T12:31:57Z',
#   'pushed_at': '2020-04-03T18:53:09Z',
#   'git_url': 'git://github.com/romulovieira777/22-Tabuada.git',
#   'ssh_url': 'git@github.com:romulovieira777/22-Tabuada.git',
#   'clone_url': 'https://github.com/romulovieira777/22-Tabuada.git',
#   'svn_url': 'https://github.com/romulovieira777/22-Tabuada',
#   'homepage': None,
#   'size': 6,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 252814892,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTI4MTQ4OTI=',
#   'name': '32-Fahrenheit_para_Celsius',
#   'full_name': 'romulovieira777/32-Fahrenheit_para_Celsius',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/32-Fahrenheit_para_Celsius',
#   'description': '32 - Fahrenheit para Celsius',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius/pulls{/number}',
# ...
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem/deployments',
#   'created_at': '2021-08-18T13:54:07Z',
#   'updated_at': '2021-08-18T14:06:04Z',
#   'pushed_at': '2021-08-18T14:06:01Z',
#   'git_url': 'git://github.com/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem.git',
#   'ssh_url': 'git@github.com:romulovieira777/Criando_Ecossistema_Big_Data_Nuvem.git',
#   'clone_url': 'https://github.com/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem.git',
#   'svn_url': 'https://github.com/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem',
#   'homepage': None,
#   'size': 224,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main'},
#  {'id': 281780494,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyODE3ODA0OTQ=',
#   'name': 'Curso_Banco_de_Dados_Oracle',
#   'full_name': 'romulovieira777/Curso_Banco_de_Dados_Oracle',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/Curso_Banco_de_Dados_Oracle',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle/deployments',
#   'created_at': '2020-07-22T20:50:24Z',
#   'updated_at': '2020-12-12T15:48:19Z',
#   'pushed_at': '2020-12-12T15:48:17Z',
#   'git_url': 'git://github.com/romulovieira777/Curso_Banco_de_Dados_Oracle.git',
#   'ssh_url': 'git@github.com:romulovieira777/Curso_Banco_de_Dados_Oracle.git',
#   'clone_url': 'https://github.com/romulovieira777/Curso_Banco_de_Dados_Oracle.git',
#   'svn_url': 'https://github.com/romulovieira777/Curso_Banco_de_Dados_Oracle',
#   'homepage': None,
#   'size': 7,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'PLSQL',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'},
#  {'id': 283531035,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyODM1MzEwMzU=',
#   'name': 'Curso_Banco_MySQL_2019',
#   'full_name': 'romulovieira777/Curso_Banco_MySQL_2019',
#   'private': False,
#   'owner': {'login': 'romulovieira777',
#    'id': 61069548,
#    'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romulovieira777',
#    'html_url': 'https://github.com/romulovieira777',
#    'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#    'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#    'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#    'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#    'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/romulovieira777/Curso_Banco_MySQL_2019',
#   'description': 'Curso de Banco de Dados Udemy',
#   'fork': False,
#   'url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019',
#   'forks_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/forks',
#   'keys_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/teams',
#   'hooks_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/hooks',
#   'issue_events_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/events',
#   'assignees_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/tags',
#   'blobs_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/languages',
#   'stargazers_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/stargazers',
#   'contributors_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/contributors',
#   'subscribers_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/subscribers',
#   'subscription_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/subscription',
#   'commits_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/merges',
#   'archive_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/downloads',
#   'issues_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019/deployments',
#   'created_at': '2020-07-29T15:08:52Z',
#   'updated_at': '2020-12-12T15:47:31Z',
#   'pushed_at': '2020-12-12T15:47:29Z',
#   'git_url': 'git://github.com/romulovieira777/Curso_Banco_MySQL_2019.git',
#   'ssh_url': 'git@github.com:romulovieira777/Curso_Banco_MySQL_2019.git',
#   'clone_url': 'https://github.com/romulovieira777/Curso_Banco_MySQL_2019.git',
#   'svn_url': 'https://github.com/romulovieira777/Curso_Banco_MySQL_2019',
#   'homepage': None,
#   'size': 60,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master'}]

# %%
repos = response.json()

# %%
type(repos)
# Out:
# list

# %%
len(repos)
# Out:
# 30

# %%
repos[0]
# Out:
# {'id': 251727685,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyNTE3Mjc2ODU=',
#  'name': '16-Bingo',
#  'full_name': 'romulovieira777/16-Bingo',
#  'private': False,
#  'owner': {'login': 'romulovieira777',
#   'id': 61069548,
#   'node_id': 'MDQ6VXNlcjYxMDY5NTQ4',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/61069548?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/romulovieira777',
#   'html_url': 'https://github.com/romulovieira777',
#   'followers_url': 'https://api.github.com/users/romulovieira777/followers',
#   'following_url': 'https://api.github.com/users/romulovieira777/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/romulovieira777/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/romulovieira777/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/romulovieira777/subscriptions',
#   'organizations_url': 'https://api.github.com/users/romulovieira777/orgs',
#   'repos_url': 'https://api.github.com/users/romulovieira777/repos',
#   'events_url': 'https://api.github.com/users/romulovieira777/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/romulovieira777/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/romulovieira777/16-Bingo',
#  'description': None,
#  'fork': False,
#  'url': 'https://api.github.com/repos/romulovieira777/16-Bingo',
#  'forks_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/forks',
#  'keys_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/teams',
#  'hooks_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/hooks',
#  'issue_events_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/events',
#  'assignees_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/tags',
#  'blobs_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/languages',
#  'stargazers_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/stargazers',
#  'contributors_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/contributors',
#  'subscribers_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/subscribers',
#  'subscription_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/subscription',
#  'commits_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/merges',
#  'archive_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/downloads',
#  'issues_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/romulovieira777/16-Bingo/deployments',
#  'created_at': '2020-03-31T20:47:26Z',
#  'updated_at': '2020-05-26T12:33:53Z',
#  'pushed_at': '2020-03-31T20:53:40Z',
#  'git_url': 'git://github.com/romulovieira777/16-Bingo.git',
#  'ssh_url': 'git@github.com:romulovieira777/16-Bingo.git',
#  'clone_url': 'https://github.com/romulovieira777/16-Bingo.git',
#  'svn_url': 'https://github.com/romulovieira777/16-Bingo',
#  'homepage': None,
#  'size': 6,
#  'stargazers_count': 0,
#  'watchers_count': 0,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': {'key': 'apache-2.0',
#   'name': 'Apache License 2.0',
#   'spdx_id': 'Apache-2.0',
#   'url': 'https://api.github.com/licenses/apache-2.0',
#   'node_id': 'MDc6TGljZW5zZTI='},
#  'allow_forking': True,
#  'is_template': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 0,
#  'open_issues': 0,
#  'watchers': 0,
#  'default_branch': 'master'}

# %%
# Get names of the repos
list(map(lambda repo: repo['name'], repos))
# Out:
# ['16-Bingo',
#  '17_Antecessor_e_Sucessor',
#  '18_Menor_de_3',
#  '19-Media_dos_Alunos',
#  '2-3_Numeros_em_Ordem_Crescente',
#  '20-Loop_de_Inteiros',
#  '22-Tabuada',
#  '32-Fahrenheit_para_Celsius',
#  '34_Saque_de_banco',
#  '39_Aprovado',
#  '40_Coma_Bem',
#  'Analise_de_Dados_com_Pandas_e_Python',
#  'Analise_Orientada_a_Objetos',
#  'API_Scraping_Web_Scraping_Real_Estate_Data_PostgreSQL',
#  'Aprenda_Python_3',
#  'Aula-HTML',
#  'Aula_BD_07_04_20',
#  'Aula_BD_30_03',
#  'aula_css',
#  'Aula_des_02_04_20',
#  'aula_JavaScript',
#  'Bancos_de_Dados_SQL_e_NoSQL',
#  'Banco_de_Dados_e_SQL',
#  'Banco_de_Dados_Postegre',
#  'Big_Data_Processamento_de_Dados_com_Spark_e_PySpark',
#  'Big_Data_Processando_Dados_com_Spark_Dataframe_Scala',
#  'Business_Intelligence_SQL_Server',
#  'Criando_Ecossistema_Big_Data_Nuvem',
#  'Curso_Banco_de_Dados_Oracle',
#  'Curso_Banco_MySQL_2019']

# %%
list(map(lambda repo: repo['url'], repos))
# Out:
# ['https://api.github.com/repos/romulovieira777/16-Bingo',
#  'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor',
#  'https://api.github.com/repos/romulovieira777/18_Menor_de_3',
#  'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos',
#  'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente',
#  'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros',
#  'https://api.github.com/repos/romulovieira777/22-Tabuada',
#  'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius',
#  'https://api.github.com/repos/romulovieira777/34_Saque_de_banco',
#  'https://api.github.com/repos/romulovieira777/39_Aprovado',
#  'https://api.github.com/repos/romulovieira777/40_Coma_Bem',
#  'https://api.github.com/repos/romulovieira777/Analise_de_Dados_com_Pandas_e_Python',
#  'https://api.github.com/repos/romulovieira777/Analise_Orientada_a_Objetos',
#  'https://api.github.com/repos/romulovieira777/API_Scraping_Web_Scraping_Real_Estate_Data_PostgreSQL',
#  'https://api.github.com/repos/romulovieira777/Aprenda_Python_3',
#  'https://api.github.com/repos/romulovieira777/Aula-HTML',
#  'https://api.github.com/repos/romulovieira777/Aula_BD_07_04_20',
#  'https://api.github.com/repos/romulovieira777/Aula_BD_30_03',
#  'https://api.github.com/repos/romulovieira777/aula_css',
#  'https://api.github.com/repos/romulovieira777/Aula_des_02_04_20',
#  'https://api.github.com/repos/romulovieira777/aula_JavaScript',
#  'https://api.github.com/repos/romulovieira777/Bancos_de_Dados_SQL_e_NoSQL',
#  'https://api.github.com/repos/romulovieira777/Banco_de_Dados_e_SQL',
#  'https://api.github.com/repos/romulovieira777/Banco_de_Dados_Postegre',
#  'https://api.github.com/repos/romulovieira777/Big_Data_Processamento_de_Dados_com_Spark_e_PySpark',
#  'https://api.github.com/repos/romulovieira777/Big_Data_Processando_Dados_com_Spark_Dataframe_Scala',
#  'https://api.github.com/repos/romulovieira777/Business_Intelligence_SQL_Server',
#  'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem',
#  'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle',
#  'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019']

# %%
list(map(lambda repo: (repo['name'], repo['url']), repos))
# Out:
# [('16-Bingo', 'https://api.github.com/repos/romulovieira777/16-Bingo'),
#  ('17_Antecessor_e_Sucessor',
#   'https://api.github.com/repos/romulovieira777/17_Antecessor_e_Sucessor'),
#  ('18_Menor_de_3',
#   'https://api.github.com/repos/romulovieira777/18_Menor_de_3'),
#  ('19-Media_dos_Alunos',
#   'https://api.github.com/repos/romulovieira777/19-Media_dos_Alunos'),
#  ('2-3_Numeros_em_Ordem_Crescente',
#   'https://api.github.com/repos/romulovieira777/2-3_Numeros_em_Ordem_Crescente'),
#  ('20-Loop_de_Inteiros',
#   'https://api.github.com/repos/romulovieira777/20-Loop_de_Inteiros'),
#  ('22-Tabuada', 'https://api.github.com/repos/romulovieira777/22-Tabuada'),
#  ('32-Fahrenheit_para_Celsius',
#   'https://api.github.com/repos/romulovieira777/32-Fahrenheit_para_Celsius'),
#  ('34_Saque_de_banco',
#   'https://api.github.com/repos/romulovieira777/34_Saque_de_banco'),
#  ('39_Aprovado', 'https://api.github.com/repos/romulovieira777/39_Aprovado'),
#  ('40_Coma_Bem', 'https://api.github.com/repos/romulovieira777/40_Coma_Bem'),
#  ('Analise_de_Dados_com_Pandas_e_Python',
#   'https://api.github.com/repos/romulovieira777/Analise_de_Dados_com_Pandas_e_Python'),
#  ('Analise_Orientada_a_Objetos',
#   'https://api.github.com/repos/romulovieira777/Analise_Orientada_a_Objetos'),
#  ('API_Scraping_Web_Scraping_Real_Estate_Data_PostgreSQL',
#   'https://api.github.com/repos/romulovieira777/API_Scraping_Web_Scraping_Real_Estate_Data_PostgreSQL'),
#  ('Aprenda_Python_3',
#   'https://api.github.com/repos/romulovieira777/Aprenda_Python_3'),
#  ('Aula-HTML', 'https://api.github.com/repos/romulovieira777/Aula-HTML'),
#  ('Aula_BD_07_04_20',
#   'https://api.github.com/repos/romulovieira777/Aula_BD_07_04_20'),
#  ('Aula_BD_30_03',
#   'https://api.github.com/repos/romulovieira777/Aula_BD_30_03'),
#  ('aula_css', 'https://api.github.com/repos/romulovieira777/aula_css'),
#  ('Aula_des_02_04_20',
#   'https://api.github.com/repos/romulovieira777/Aula_des_02_04_20'),
#  ('aula_JavaScript',
#   'https://api.github.com/repos/romulovieira777/aula_JavaScript'),
#  ('Bancos_de_Dados_SQL_e_NoSQL',
#   'https://api.github.com/repos/romulovieira777/Bancos_de_Dados_SQL_e_NoSQL'),
#  ('Banco_de_Dados_e_SQL',
#   'https://api.github.com/repos/romulovieira777/Banco_de_Dados_e_SQL'),
#  ('Banco_de_Dados_Postegre',
#   'https://api.github.com/repos/romulovieira777/Banco_de_Dados_Postegre'),
#  ('Big_Data_Processamento_de_Dados_com_Spark_e_PySpark',
#   'https://api.github.com/repos/romulovieira777/Big_Data_Processamento_de_Dados_com_Spark_e_PySpark'),
#  ('Big_Data_Processando_Dados_com_Spark_Dataframe_Scala',
#   'https://api.github.com/repos/romulovieira777/Big_Data_Processando_Dados_com_Spark_Dataframe_Scala'),
#  ('Business_Intelligence_SQL_Server',
#   'https://api.github.com/repos/romulovieira777/Business_Intelligence_SQL_Server'),
#  ('Criando_Ecossistema_Big_Data_Nuvem',
#   'https://api.github.com/repos/romulovieira777/Criando_Ecossistema_Big_Data_Nuvem'),
#  ('Curso_Banco_de_Dados_Oracle',
#   'https://api.github.com/repos/romulovieira777/Curso_Banco_de_Dados_Oracle'),
#  ('Curso_Banco_MySQL_2019',
#   'https://api.github.com/repos/romulovieira777/Curso_Banco_MySQL_2019')]
