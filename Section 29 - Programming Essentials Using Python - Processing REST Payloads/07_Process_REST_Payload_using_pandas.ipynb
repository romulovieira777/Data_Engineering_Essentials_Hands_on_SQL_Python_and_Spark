# %% [markdown]
# ## Process REST Payload using Pandas
#
# Let us understand how to process REST Payload using Pandas Dataframe APIs.
#
#    * We can get details about all the public repositories using `GET /repositories` from **https://api.github.com**.
#    * As it is getting or reading data from external application the details are available via `GET`. We will have JSON Array as part of the Payload.
#    * We can convert this JSON Array to Python `list`. Each element in the list will be of type `dict`.
#    * We can apply `pandas.json_normalize` to get flattened Dataframe by passing this list of dicts.
#    * Let us understand how the data in this Pandas Dataframe can be processed using appropriate Pandas APIs as per our requeriments.

# %%
import requests

# %%
payload = requests.get("https://api.github.com/repositories").json()

# %%
# A list which contain dicts
payload
# Out:
# [{'archive_url': 'https://api.github.com/repos/mojombo/grit/{archive_format}{/ref}',
#   'assignees_url': 'https://api.github.com/repos/mojombo/grit/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/mojombo/grit/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/mojombo/grit/branches{/branch}',
#   'collaborators_url': 'https://api.github.com/repos/mojombo/grit/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/mojombo/grit/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/mojombo/grit/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/mojombo/grit/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/mojombo/grit/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/mojombo/grit/contributors',
#   'deployments_url': 'https://api.github.com/repos/mojombo/grit/deployments',
# ...

# %% [markdown]
# * Now can convert the list returned to pandas dataframe using `json_normalize`.

# %%
import pandas as pd

# %%
repos_df = pd.json_normalize(payload)

# %%
repos_df
# Out:
#      id                   node_id  ...    owner.type owner.site_admin
# 0     1      MDEwOlJlcG9zaXRvcnkx  ...          User            False
# 1    26  MDEwOlJlcG9zaXRvcnkyNg==  ...          User            False
# 2    27  MDEwOlJlcG9zaXRvcnkyNw==  ...  Organization            False
# 3    28  MDEwOlJlcG9zaXRvcnkyOA==  ...          User            False
# 4    29  MDEwOlJlcG9zaXRvcnkyOQ==  ...          User            False
# ..  ...                       ...  ...           ...              ...
# 95  364  MDEwOlJlcG9zaXRvcnkzNjQ=  ...  Organization            False
# 96  365  MDEwOlJlcG9zaXRvcnkzNjU=  ...  Organization            False
# 97  367  MDEwOlJlcG9zaXRvcnkzNjc=  ...  Organization            False
# 98  368  MDEwOlJlcG9zaXRvcnkzNjg=  ...  Organization            False
# 99  369  MDEwOlJlcG9zaXRvcnkzNjk=  ...  Organization            False
#
# [100 rows x 63 columns]

# %%
repos_df.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'owner.login', 'owner.id', 'owner.node_id',
#        'owner.avatar_url', 'owner.gravatar_id', 'owner.url', 'owner.html_url',
#        'owner.followers_url', 'owner.following_url', 'owner.gists_url',
# ...

# %%
repos_df.dtypes
# Out:
# id                            int64
# node_id                      object
# name                         object
# full_name                    object
# private                        bool
#                               ...
# owner.repos_url              object
# owner.events_url             object
# owner.received_events_url    object
# owner.type                   object
# owner.site_admin               bool
# Length: 63, dtype: object

# %%
repos_df.shape
# Out:
# (100, 63)

# %%
repos_df.count()
# Out:
# id                           100
# node_id                      100
# name                         100
# full_name                    100
# private                      100
#                             ...
# owner.repos_url              100
# owner.events_url             100
# owner.received_events_url    100
# owner.type                   100
# owner.site_admin             100
# Length: 63, dtype: int64

# %% [markdown]
# * Here are some of the tasks you can work on using `repos_df` data. We will explore the solutions using Pandas APis.

# %%
since = 369

# %%
repos = requests.get(f"https://api.github.com/repositories?since={since}").json()

# %%
repos_df = pd.json_normalize(repos)

# %%
repos_df
# Out:
#      id                   node_id  ...    owner.type owner.site_admin
# 0   370  MDEwOlJlcG9zaXRvcnkzNzA=  ...  Organization            False
# 1   371  MDEwOlJlcG9zaXRvcnkzNzE=  ...  Organization            False
# 2   372  MDEwOlJlcG9zaXRvcnkzNzI=  ...  Organization            False
# 3   374  MDEwOlJlcG9zaXRvcnkzNzQ=  ...  Organization            False
# 4   376  MDEwOlJlcG9zaXRvcnkzNzY=  ...  Organization            False
# ..  ...                       ...  ...           ...              ...
# 95  856  MDEwOlJlcG9zaXRvcnk4NTY=  ...          User            False
# 96  866  MDEwOlJlcG9zaXRvcnk4NjY=  ...          User            False
# 97  867  MDEwOlJlcG9zaXRvcnk4Njc=  ...          User            False
# 98  872  MDEwOlJlcG9zaXRvcnk4NzI=  ...          User            False
# 99  876  MDEwOlJlcG9zaXRvcnk4NzY=  ...          User            False
#
# [100 rows x 63 columns]

# %% [markdown]
# * Get number of repositories.

# %%
repos_df.shape
# Out:
# (100, 63)

# %%
repos_df.shape[0]
# Out:
# 100

# %% [markdown]
# * Get repository name, url and owner type of all repositories.

# %%
repos_df
# Out:
#      id                   node_id  ...    owner.type owner.site_admin
# 0   370  MDEwOlJlcG9zaXRvcnkzNzA=  ...  Organization            False
# 1   371  MDEwOlJlcG9zaXRvcnkzNzE=  ...  Organization            False
# 2   372  MDEwOlJlcG9zaXRvcnkzNzI=  ...  Organization            False
# 3   374  MDEwOlJlcG9zaXRvcnkzNzQ=  ...  Organization            False
# 4   376  MDEwOlJlcG9zaXRvcnkzNzY=  ...  Organization            False
# ..  ...                       ...  ...           ...              ...
# 95  856  MDEwOlJlcG9zaXRvcnk4NTY=  ...          User            False
# 96  866  MDEwOlJlcG9zaXRvcnk4NjY=  ...          User            False
# 97  867  MDEwOlJlcG9zaXRvcnk4Njc=  ...          User            False
# 98  872  MDEwOlJlcG9zaXRvcnk4NzI=  ...          User            False
# 99  876  MDEwOlJlcG9zaXRvcnk4NzY=  ...          User            False
#
# [100 rows x 63 columns]

# %%
repos_df[['name', 'url','owner.type']]
# Out:
#                     name  ...    owner.type
# 0   imap_authenticatable  ...  Organization
# 1         random_finders  ...  Organization
# 2            with_action  ...  Organization
# 3              graticule  ...  Organization
# 4                 tinder  ...  Organization
# ..                   ...  ...           ...
# 95                gemify  ...          User
# 96                  mor7  ...          User
# 97                  blog  ...          User
# 98              hairball  ...          User
# 99             merb-core  ...          User
#
# [100 rows x 3 columns]

# %% [markdown]
# * Get all unique or distinct owner types of the repositories. The output should be of type **list.**

# %%
repos_df['owner.type']
# Out:
# 0     Organization
# 1     Organization
# 2     Organization
# 3     Organization
# 4     Organization
#           ...
# 95            User
# 96            User
# 97            User
# 98            User
# 99            User
# Name: owner.type, Length: 100, dtype: object

# %%
repos_df['owner.type'].unique()
# Out:
# array(['Organization', 'User'], dtype=object)

# %%
list(repos_df['owner.type'].unique())
# Out:
# ['Organization', 'User']

# %% [markdown]
# * Get number of repositories where owner type is **User.**

# %%
repos_df['owner.type'] == 'User'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: owner.type, Length: 100, dtype: bool

# %%
repos_df[repos_df['owner.type'] == 'User']
# Out:
#      id                   node_id  ... owner.type owner.site_admin
# 5   377  MDEwOlJlcG9zaXRvcnkzNzc=  ...       User            False
# 6   379  MDEwOlJlcG9zaXRvcnkzNzk=  ...       User            False
# 7   386  MDEwOlJlcG9zaXRvcnkzODY=  ...       User            False
# 8   388  MDEwOlJlcG9zaXRvcnkzODg=  ...       User            False
# 9   408  MDEwOlJlcG9zaXRvcnk0MDg=  ...       User             True
# ..  ...                       ...  ...        ...              ...
# 95  856  MDEwOlJlcG9zaXRvcnk4NTY=  ...       User            False
# 96  866  MDEwOlJlcG9zaXRvcnk4NjY=  ...       User            False
# 97  867  MDEwOlJlcG9zaXRvcnk4Njc=  ...       User            False
# 98  872  MDEwOlJlcG9zaXRvcnk4NzI=  ...       User            False
# 99  876  MDEwOlJlcG9zaXRvcnk4NzY=  ...       User            False
#
# [93 rows x 63 columns]

# %%
repos_df[repos_df['owner.type'] == 'User'].shape
# Out:
# (93, 63)

# %%
repos_df[repos_df['owner.type'] == 'User'].shape[0]
# Out:
# 93

# %% [markdown]
# * Get number of repositories where owner type is **Organization.**

# %%
repos_df[repos_df['owner.type'] == 'Organization'].shape[0]
# Out:
# 7

# %% [markdown]
# * Get number of repositories by each owner type.

# %%
repos_df.groupby('owner.type')

# %%
repos_df.groupby('owner.type')['owner.type'].count()
# Out:
# owner.type
# Organization     7
# User            93
# Name: owner.type, dtype: int64

# %% [markdown]
# * Sort the data by owner type and then by id. Ensure that data is sorted by id as numeric.

# %%
repos_df.dtypes
# Out:
# id                            int64
# node_id                      object
# name                         object
# full_name                    object
# private                        bool
#                               ...
# owner.repos_url              object
# owner.events_url             object
# owner.received_events_url    object
# owner.type                   object
# owner.site_admin               bool
# Length: 63, dtype: object

# %%
repos_df.sort_values(by=['owner.type', 'id']).head(10)
# Out:
#      id                   node_id  ...    owner.type owner.site_admin
# 0   370  MDEwOlJlcG9zaXRvcnkzNzA=  ...  Organization            False
# 1   371  MDEwOlJlcG9zaXRvcnkzNzE=  ...  Organization            False
# 2   372  MDEwOlJlcG9zaXRvcnkzNzI=  ...  Organization            False
# 3   374  MDEwOlJlcG9zaXRvcnkzNzQ=  ...  Organization            False
# 4   376  MDEwOlJlcG9zaXRvcnkzNzY=  ...  Organization            False
# 15  426  MDEwOlJlcG9zaXRvcnk0MjY=  ...  Organization            False
# 88  807  MDEwOlJlcG9zaXRvcnk4MDc=  ...  Organization            False
# 5   377  MDEwOlJlcG9zaXRvcnkzNzc=  ...          User            False
# 6   379  MDEwOlJlcG9zaXRvcnkzNzk=  ...          User            False
# 7   386  MDEwOlJlcG9zaXRvcnkzODY=  ...          User            False
#
# [10 rows x 63 columns]
